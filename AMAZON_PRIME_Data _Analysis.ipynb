# %% [markdown]
# # Part 1: Basic Pandas Operations

# %% [markdown]
# 1)Load and explore the dataset:

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset using Pandas
df = pd.read_csv('amazon_prime_titles.csv')

# %%
# Display first and last 5 rows
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %%
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan     NaN        NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaN
#
#       release_year rating   duration                listed_in  \
# 9663          1940     7+     60 min                   Comedy
# 9664          2018    13+  4 Seasons                 TV Shows
# 9665          2008      R     90 min                   Action
# 9666          2021  TV-MA   1 Season            Drama, Sports
# 9667          2010      R    103 min  Action, Drama, Suspense
#
#                                             description
# 9663  New York City street principles get an East Si...
# 9664  This is Earth, 2100AD - and these are the adve...
# 9665  In war-torn Eastern Europe, a world-weary grou...
# 9666  The series tells the story of Diego Maradona, ...
# 9667  Harry Brown, starring two-time Academy Award w...

# %%
# Print the shape, column names, and info summary of the dataset
df.shape
# Out:
# (9668, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %% [markdown]
# 2) Data Cleaning:

# %%
# Check for missing values and count them per column
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Drop all rows where the title or type is missing
df.dropna(subset=['title', 'type'], inplace=True)

# %%
df['date_added'] = pd.to_datetime(df['date_added'].str.strip())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    datetime64[ns]
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 981.9+ KB

# %% [markdown]
# 3)Filtering and indexing:

# %%
# Show only movies released after 2015
df[df['release_year']>2015]
# Out:
#      show_id     type                    title  \
# 1         s2    Movie     Take Care Good Night
# 2         s3    Movie     Secrets of Deception
# 6         s7    Movie                Hired Gun
# 7         s8    Movie             Grease Live!
# 8         s9    Movie          Global Meltdown
# ...      ...      ...                      ...
# 9656   s9657    Movie       Anaganaga Oka Nenu
# 9660   s9661    Movie       The Man in the Hat
# 9662   s9663    Movie                    River
# 9664   s9665  TV Show            Planet Patrol
# 9666   s9667  TV Show  Maradona: Blessed Dream
#
#                                  director  \
# 1                            Girish Joshi
# 2                             Josh Webber
# 6                             Fran Strine
# 7             Thomas Kail, Alex Rudzinski
# 8                           Daniel Gilboy
# ...                                   ...
# 9656                             Vamshi P
# 9660  John-Paul Davidson, Stephen Warbeck
# 9662                           Emily Skye
# 9664                                  NaN
# 9666                                  NaN
#
#                                                    cast        country  \
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
# 6     Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...  United States
# 7     Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...  United States
# 8     Michael Paré, Leanne Khol Young, Patrick J. Ma...         Canada
# ...                                                 ...            ...
# 9656       Vijay, Sweta chaudhary, NNR CHOWDARY, Hariya            NaN
# 9660             Ciaran Hinds, Stephen Dillane, Maïwenn            NaN
# 9662  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...            NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...            NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...            NaN
#
#      date_added  release_year rating   duration  \
# 1    2021-03-30          2018    13+    110 min
# 2    2021-03-30          2017    NaN     74 min
# 6    2021-03-30          2017    NaN     98 min
# 7    2021-03-30          2016    NaN    131 min
# 8    2021-03-30          2017    NaN     87 min
# ...         ...           ...    ...        ...
# 9656        NaT          2021    18+    135 min
# 9660        NaT          2021    13+     96 min
# 9662        NaT          2021    16+     93 min
# 9664        NaT          2018    13+  4 Seasons
# 9666        NaT          2021  TV-MA   1 Season
#
#                               listed_in  \
# 1                  Drama, International
# 2               Action, Drama, Suspense
# 6         Documentary, Special Interest
# 7                                Comedy
# 8     Action, Science Fiction, Suspense
# ...                                 ...
# 9656            Action, Drama, Suspense
# 9660                             Comedy
# 9662   Drama, Science Fiction, Suspense
# 9664                           TV Shows
# 9666                      Drama, Sports
#
#                                             description
# 1     A Metro Family decides to fight a Cyber Crimin...
# 2     After a man discovers his wife is cheating on ...
# 6     They are the "First Call, A-list" musicians, j...
# 7     This honest, uncompromising comedy chronicles ...
# 8     A helicopter pilot and an environmental scient...
# ...                                                 ...
# 9656  Peter(hero) Who went to the forest to find a c...
# 9660  The Man in the Hat journeys through France in ...
# 9662  River is a grounded Sci-Fi mystery Thriller, t...
# 9664  This is Earth, 2100AD - and these are the adve...
# 9666  The series tells the story of Diego Maradona, ...
#
# [5039 rows x 12 columns]

# %%
# Filter all shows from the country India
df[df['country'].str.lower() == 'india']
# Out:
#      show_id   type                 title         director  \
# 1         s2  Movie  Take Care Good Night     Girish Joshi
# 107     s108  Movie                Whoop!     Kreeti Gogia
# 142     s143  Movie   Wedding Cha Shinema  Saleel Kulkarni
# 178     s179  Movie              Viswasam             Siva
# 180     s181  Movie                 Virus       Aashiq Abu
# ...      ...    ...                   ...              ...
# 7505   s7506  Movie   The Priest (Telugu)  Jofin T. Chacko
# 8366   s8367  Movie            Aashiqui 2       Mohit Suri
# 8569   s8570  Movie    The Priest (Tamil)  Jofin T. Chacko
# 8825   s8826  Movie        Sunny (4K UHD)   Ranjith Sankar
# 8826   s8827  Movie                 Sunny   Ranjith Sankar
#
#                                                    cast country date_added  \
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India 2021-03-30
# 107                                        Abish Mathew   India        NaT
# 142   Shivraj Waichal, Rucha Inamdar, Mukta Barve, P...   India        NaT
# 178                             Ajith Kumar, Nayanthara   India        NaT
# 180         Revathy, Kunchako Boban, Parvathy Thiruvoth   India        NaT
# ...                                                 ...     ...        ...
# 7505  Mammootty, Manju Warrier, Ameya Mathew, Nikhil...   India        NaT
# 8366  Aditya Roy Kapoor, Shraddha Kapoor, Shaad Rand...   India        NaT
# 8569  Mammootty, Manju Warrier, Ameya Mathew, Nikhil...   India        NaT
# 8825                                          Jayasurya   India        NaT
# 8826                                          Jayasurya   India        NaT
#
#       release_year rating duration                         listed_in  \
# 1             2018    13+  110 min              Drama, International
# 107           2018    18+   64 min  Arts, Entertainment, and Culture
# 142           2019    ALL  138 min             Comedy, International
# 178           2019    13+  151 min      Action, Drama, International
# 180           2019    ALL  149 min  Drama, Science Fiction, Suspense
# ...            ...    ...      ...                               ...
# 7505          2021    13+  145 min                          Suspense
# 8366          2013    ALL  127 min            International, Romance
# 8569          2021    13+  145 min                          Suspense
# 8825          2021  PG-13   93 min                   Drama, Suspense
# 8826          2021  PG-13   93 min                   Drama, Suspense
#
#                                             description
# 1     A Metro Family decides to fight a Cyber Crimin...
# 107   Abish Mathew is the world's greatest stand-up ...
# 142   An aspiring filmmaker reluctantly takes up the...
# 178   A village ruffian, who settles disputes in his...
# 180   Virus is a fiction based on true events, revol...
# ...                                                 ...
# 7505  Father Carmen, a priest, joins hands with the ...
# 8366  Rahul loses his fans and fame due to alcoholis...
# 8569  Father Carmen, a priest, joins hands with the ...
# 8825  The life of a failed musician, sunny takes a d...
# 8826  The life of a failed musician, sunny takes a d...
#
# [229 rows x 12 columns]

# %%
# Select only Movie type entries with duration over 90 minutes
df2 = df[df['duration'].str.contains('min', na=False)]
df2['duration_minutes'] = pd.to_numeric(
    df['duration'].str.extract(r'(\d+)')[0],
    errors='coerce'
)
df2[((df2['type'].str.lower() == 'movie') & (df2['duration_minutes'] > 90))]
# Out:
# c:\users\varaprasad\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      show_id   type                       title  \
# 0         s1  Movie         The Grand Seduction
# 1         s2  Movie        Take Care Good Night
# 6         s7  Movie                   Hired Gun
# 7         s8  Movie                Grease Live!
# 9        s10  Movie              David's Mother
# ...      ...    ...                         ...
# 9656   s9657  Movie          Anaganaga Oka Nenu
# 9659   s9660  Movie  10 Things I Hate About You
# 9660   s9661  Movie          The Man in the Hat
# 9662   s9663  Movie                       River
# 9667   s9668  Movie                 Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 6                             Fran Strine
# 7             Thomas Kail, Alex Rudzinski
# 9                   Robert Allan Ackerman
# ...                                   ...
# 9656                             Vamshi P
# 9659                           Gil Junger
# 9660  John-Paul Davidson, Stephen Warbeck
# 9662                           Emily Skye
# 9667                        Daniel Barber
#
#                                                    cast        country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 6     Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...  United States
# 7     Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...  United States
# 9       Kirstie Alley, Sam Waterston, Stockard Channing  United States
# ...                                                 ...            ...
# 9656       Vijay, Sweta chaudhary, NNR CHOWDARY, Hariya            NaN
# 9659  Heath Ledger, Julia Stiles, Joseph Gordon-Levi...            NaN
# 9660             Ciaran Hinds, Stephen Dillane, Maïwenn            NaN
# 9662  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...            NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...            NaN
#
#      date_added  release_year rating duration  \
# 0    2021-03-30          2014    NaN  113 min
# 1    2021-03-30          2018    13+  110 min
# 6    2021-03-30          2017    NaN   98 min
# 7    2021-03-30          2016    NaN  131 min
# 9    2021-04-01          1994    NaN   92 min
# ...         ...           ...    ...      ...
# 9656        NaT          2021    18+  135 min
# 9659        NaT          1999  PG-13   97 min
# 9660        NaT          2021    13+   96 min
# 9662        NaT          2021    16+   93 min
# 9667        NaT          2010      R  103 min
#
#                              listed_in  \
# 0                        Comedy, Drama
# 1                 Drama, International
# 6        Documentary, Special Interest
# 7                               Comedy
# 9                                Drama
# ...                                ...
# 9656           Action, Drama, Suspense
# 9659            Comedy, Drama, Romance
# 9660                            Comedy
# 9662  Drama, Science Fiction, Suspense
# 9667           Action, Drama, Suspense
#
#                                             description  duration_minutes
# 0     A small fishing village must procure a local d...               113
# 1     A Metro Family decides to fight a Cyber Crimin...               110
# 6     They are the "First Call, A-list" musicians, j...                98
# 7     This honest, uncompromising comedy chronicles ...               131
# 9     Sally Goodson is a devoted mother to her autis...                92
# ...                                                 ...               ...
# 9656  Peter(hero) Who went to the forest to find a c...               135
# 9659  On the first day at his new school, Cameron in...                97
# 9660  The Man in the Hat journeys through France in ...                96
# 9662  River is a grounded Sci-Fi mystery Thriller, t...                93
# 9667  Harry Brown, starring two-time Academy Award w...               103
#
# [4027 rows x 13 columns]

# %% [markdown]
# 4)Column operations:

# %%
# Create a new column called `release_decade` based on the release_year
df['release_decade'] = df['release_year'].astype(str).str[:-1]+'0s'
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#      date_added  release_year rating   duration                listed_in  \
# 0    2021-03-30          2014    NaN    113 min            Comedy, Drama
# 1    2021-03-30          2018    13+    110 min     Drama, International
# 2    2021-03-30          2017    NaN     74 min  Action, Drama, Suspense
# 3    2021-03-30          2014    NaN     69 min              Documentary
# 4    2021-03-30          1989    NaN     45 min           Drama, Fantasy
# ...         ...           ...    ...        ...                      ...
# 9663        NaT          1940     7+     60 min                   Comedy
# 9664        NaT          2018    13+  4 Seasons                 TV Shows
# 9665        NaT          2008      R     90 min                   Action
# 9666        NaT          2021  TV-MA   1 Season            Drama, Sports
# 9667        NaT          2010      R    103 min  Action, Drama, Suspense
#
#                                             description release_decade
# 0     A small fishing village must procure a local d...          2010s
# 1     A Metro Family decides to fight a Cyber Crimin...          2010s
# 2     After a man discovers his wife is cheating on ...          2010s
# 3     Pink breaks the mold once again, bringing her ...          2010s
# 4     Teenage Matt Banting wants to work with a famo...          1980s
# ...                                                 ...            ...
# 9663  New York City street principles get an East Si...          1940s
# 9664  This is Earth, 2100AD - and these are the adve...          2010s
# 9665  In war-torn Eastern Europe, a world-weary grou...          2000s
# 9666  The series tells the story of Diego Maradona, ...          2020s
# 9667  Harry Brown, starring two-time Academy Award w...          2010s
#
# [9668 rows x 13 columns]

# %%
# Display unique values in type, rating, and country
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['rating'].unique()
# Out:
# array([nan, '13+', 'ALL', '18+', 'R', 'TV-Y', 'TV-Y7', 'NR', '16+',
#        'TV-PG', '7+', 'TV-14', 'TV-NR', 'TV-G', 'PG-13', 'TV-MA', 'G',
#        'PG', 'NC-17', 'UNRATED', '16', 'AGES_16_', 'AGES_18_', 'ALL_AGES',
#        'NOT_RATE'], dtype=object)

# %%
all_countries = df['country'].str.split(',').explode().str.strip()
unique_countries = all_countries.unique()
unique_countries
# Out:
# array(['Canada', 'India', 'United States', 'United Kingdom', 'France',
#        'Spain', nan, 'Italy', 'Germany', 'Japan', 'China', 'Denmark',
#        'Czech Republic', 'Netherlands', 'Ireland', 'Thailand', 'Brazil',
#        'Switzerland', 'Australia', 'Belgium', 'Chile', 'Argentina',
#        'Mexico', 'Sweden', 'New Zealand', 'Portugal', 'Hungary', 'Iran',
#        'Luxembourg', 'South Africa', 'Austria', 'Monaco', 'Egypt',
#        'United Arab Emirates', 'Singapore', 'South Korea', 'Afghanistan',
#        'Colombia', 'Norway', 'Kosovo', 'Kazakhstan', 'Malaysia', 'Poland',
#        'Albania', 'Georgia', 'Hong Kong'], dtype=object)

# %% [markdown]
# # Part 2: GroupBy Operations

# %% [markdown]
# 5)Aggregations:

# %%
# Group by type and count the number of titles in each category
df.groupby('type')['title'].count()
# Out:
# type
# Movie      7814
# TV Show    1854
# Name: title, dtype: int64

# %%
# Group by country and find the top 5 countries with the most titles
df.groupby('country')['title'].count().sort_values(ascending=False).head(5)
# Out:
# country
# United States                    253
# India                            229
# United Kingdom                    28
# Canada                            16
# United Kingdom, United States     12
# Name: title, dtype: int64

# %%
# Group by rating and find average release year for each rating type
df.groupby('rating')['release_year'].mean()
# Out:
# rating
# 13+         2003.767123
# 16          2005.000000
# 16+         2013.248222
# 18+         2012.567176
# 7+          2003.932468
# AGES_16_    2017.000000
# AGES_18_    2017.000000
# ALL         2012.048107
# ALL_AGES    2020.000000
# G           2002.924731
# NC-17       2020.333333
# NOT_RATE    1985.666667
# NR          1999.883408
# PG          1990.747036
# PG-13       2004.882952
# R           2005.527723
# TV-14       2014.865385
# TV-G        2006.888889
# TV-MA       2017.415584
# TV-NR       2015.790476
# TV-PG       2010.402367
# TV-Y        2009.824324
# TV-Y7       2011.205128
# UNRATED     2014.333333
# Name: release_year, dtype: float64

# %% [markdown]
# 6)Multiple aggregations:

# %%
# Group by release_year and show:
# - Total number of titles

df.groupby('release_year').agg(
    total_no_of_titles = ('title', 'count')
)
# Out:
#               total_no_of_titles
# release_year
# 1920                           3
# 1922                           2
# 1923                           1
# 1924                           1
# 1925                           8
# ...                          ...
# 2017                         562
# 2018                         623
# 2019                         929
# 2020                         962
# 2021                        1442
#
# [100 rows x 1 columns]

# %%
# - Count of Movies and TV Shows separately
df.groupby('release_year')['type'].value_counts().unstack(fill_value=0)
# Out:
# type          Movie  TV Show
# release_year
# 1920              3        0
# 1922              2        0
# 1923              1        0
# 1924              1        0
# 1925              8        0
# ...             ...      ...
# 2017            404      158
# 2018            438      185
# 2019            730      199
# 2020            736      226
# 2021           1139      303
#
# [100 rows x 2 columns]

# %% [markdown]
# 7) Advanced:

# %%
# Create a new column `is_recent` True if `release_year` > 2015
df['is_recent'] = df['release_year']>2015
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan     NaN        NaT
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaT
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaT
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaT
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaT
#
#       release_year rating   duration                listed_in  \
# 9663          1940     7+     60 min                   Comedy
# 9664          2018    13+  4 Seasons                 TV Shows
# 9665          2008      R     90 min                   Action
# 9666          2021  TV-MA   1 Season            Drama, Sports
# 9667          2010      R    103 min  Action, Drama, Suspense
#
#                                             description release_decade  \
# 9663  New York City street principles get an East Si...          1940s
# 9664  This is Earth, 2100AD - and these are the adve...          2010s
# 9665  In war-torn Eastern Europe, a world-weary grou...          2000s
# 9666  The series tells the story of Diego Maradona, ...          2020s
# 9667  Harry Brown, starring two-time Academy Award w...          2010s
#
#       is_recent
# 9663      False
# 9664       True
# 9665      False
# 9666       True
# 9667      False

# %%
# Group by country and count how many recent shows are there per country
df.groupby('country')['is_recent'].sum()
# Out:
# country
# Afghanistan, France                          1
# Australia                                    2
# Australia, Colombia, United Kingdom          1
# Australia, United States, Germany            1
# Austria                                      1
#                                             ..
# United States, United Arab Emirates          0
# United States, United Kingdom                1
# United States, United Kingdom, Canada        1
# United States, United Kingdom, Germany       0
# United States, United Kingdom, Kazakhstan    0
# Name: is_recent, Length: 86, dtype: int64

# %% [markdown]
# # Part 3: Analysis Questions

# %%
# 1. What is the most common rating for TV Shows?
df['rating'].value_counts().head(1)

# This is the most common rating because. I have count the values  on the basis of rating value_counts that give the first element is the most frequently occurring element.
# Out:
# 13+    2117
# Name: rating, dtype: int64

# %%
# Which country has the most content on amazon_prime?
df['country'].value_counts().head(1)

# This is the most content on the basis of country on Prime because. I have count the values on the basis of country value_counts that give the first element is the most frequently occurring element.
# Out:
# United States    253
# Name: country, dtype: int64

# %%
# Are most Amazon_prime titles older or recent (after 2015)?
df['is_recent'].value_counts()

# Recent, you can see below
# Out:
# True     5039
# False    4629
# Name: is_recent, dtype: int64

# %%
# Whats the average release year for Amazon prime Movies?
average_release_year_movies = df[df['type'].str.lower()=='movie']['release_year'].mean()
print(f"Average release year for Amazon_prime Movies: {average_release_year_movies:.2f}")
# Out:
# Average release year for Amazon_prime Movies: 2006.87

# %% [markdown]
# Conclusion:
# The analysis reveals that the majority of Amazon_prime content comes from the United States, with movies and TV shows spanning many decades. Most titles are recent, released after 2015. The most common rating for TV shows tends to be 13+(TV-MA), indicating mature content is prevalent on the platform.
